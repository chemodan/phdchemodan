# %% [markdown]
# Get files from meltwater for the Seattle area

# %%
from typing import Dict, List, Tuple
import pandas as pd
import numpy as np
import datetime

from IPython import display

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import dates
import networkx as nx

from sklearn.ensemble import RandomForestRegressor
from sklearn. model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import os

plt.rcParams.update({'font.size': 16})

# %run ./meltwater_tweet_sentiment.ipynb

REGION = 'seattle'

# %%
# %run ./meltwater_tweet_sentiment.ipynb
ts = tweetSentiment(rawDir='./../meltwater/final_query/all_topics_', region=REGION)
dfS = ts.getData()
# Out:
# Reading data from ./../meltwater/final_query/all_topics_seattle.csv
# Got all tweets data for seattle (1286526 rows) from ./../meltwater/final_query/all_topics_seattle.csv

# %%
"""Sentiment of All Tweets"""
# %run ./meltwater_tweet_sentiment.ipynb
ts = tweetSentiment(rawDir='./../meltwater/final_query/all_topics__', region=REGION)
ts.analyzeSentiment(dfS, True, True, 'Tweets')

"""Sentiment of Shared (RT or QT) Tweets"""
# %run ./meltwater_tweet_sentiment.ipynb
ts = tweetSentiment(rawDir='./../meltwater/final_query/all_topics__', region=REGION)
ts.analyzeSharedTweetsSentiment(dfS, True, True)
# Out:
# C:\Users\alexg\AppData\Roaming\Python\Python36\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# We have 1286526 tweets, of which 1017479 (0.791) are retweets or quotes
# We have 224532 unique key phrases
# C:\Users\alexg\AppData\Roaming\Python\Python36\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %% [markdown]
# https://www.king5.com/article/news/local/protests/clean-up-continues-a-day-after-seattles-chop-zone-was-dismantled/281-ec8c3e41-ec03-4afa-87d5-d203dd924d21
