# %% [markdown]
# Analyze Collected Tweet Metadata

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid
from sklearn import decomposition
import statsmodels.regression.linear_model as lm
from sklearn.ensemble import RandomForestRegressor 
from typing import List, Tuple, Dict

import itertools

MYDIR = "./"
ALLFILES = os.listdir(MYDIR)
MYFILES = [ff for ff in ALLFILES if ("all_tweets" in ff)]
MYFILES
# Out:
# ['all_tweets_2020-10-12__01_23_57.csv',
#  'all_tweets_2020-10-12__22_35_54.csv',
#  'all_tweets_2020-10-12__22_39_58.csv',
#  'all_tweets_2020-10-12__22_49_41.csv',
#  'all_tweets_2020-10-12__23_00_59.csv',
#  'all_tweets_2020-10-13__00_48_10.csv',
#  'all_tweets_2020-10-13__00_57_56.csv',
#  'all_tweets_2020-10-13__09_22_44.csv',
#  'all_tweets_2020-10-13__09_22_54.csv',
#  'all_tweets_2020-10-13__19_53_14.csv',
#  'all_tweets_2020-10-13__19_53_21.csv',
#  'all_tweets_2020-10-13__21_13_06.csv',
#  'all_tweets_2020-10-13__21_16_26.csv',
#  'all_tweets_2020-10-13__21_35_56.csv',
#  'all_tweets_2020-10-15__20_07_50.csv',
#  'all_tweets_2020-10-15__21_34_26.csv',
#  'all_tweets_2020-10-15__21_38_08.csv']

# %%
MY_BIG_TOPICS = {
          "race": ["black", "racism", "racial"],
          "politics": ["trump", "biden", "elections", "democrat", "republican",],
          "covid": ["covid", "corona", "pandemic", "virus", "vaccine"],
          "police": ["cops", "police"],
          "wildfires": ["fires", "wildfires", "air quality"],
         }
TOPICS = []
for tt in MY_BIG_TOPICS.values():
    TOPICS.extend(tt)
print(TOPICS)

def getBigTopic(topic) -> str:
    for kk in MY_BIG_TOPICS.keys():
        if topic in MY_BIG_TOPICS[kk]:
            return kk
    return None
# Out:
# ['black', 'racism', 'racial', 'trump', 'biden', 'elections', 'democrat', 'republican', 'covid', 'corona', 'pandemic', 'virus', 'vaccine', 'cops', 'police', 'fires', 'wildfires', 'air quality']

# %%
tweetsHT = {} # Dict[str, pd.DataFrame]
for ff in MYFILES:
    tweetsHT[ff] = pd.read_csv(MYDIR + ff)
    
tweetsDF = pd.concat(tweetsHT).drop_duplicates().reset_index(drop=True)
print(f"Gathered the data collected from twitter ({len(tweetsDF)} rows)")
# Out:
# Gathered the data collected from twitter (80453 rows)

# %%
tweetsDF["big_topic"] = tweetsDF.the_topic.apply(lambda x: getBigTopic(x))
location_legit = tweetsDF.loc[~tweetsDF.location.isin(TOPICS)]
location_none = tweetsDF.loc[tweetsDF.location.isin(TOPICS)]
location_none.location = None

tweetsDF = pd.concat([location_legit, location_none]).reset_index(drop=True)
"""
Get counts of tweets by location and big_topic
"""
totals = pd.DataFrame(tweetsDF.groupby(["location", "topic", "the_topic", "big_topic"]).count()["id"]).reset_index()
totals.rename(columns = {"id": "count"}, inplace=True)
"""
Get counts of retweets by location and big_topic
"""
retweets = pd.DataFrame(tweetsDF.groupby(["location", "topic", "the_topic", "big_topic"]).sum()["retweet_count"]).reset_index()
summaries = totals.merge(retweets, on=["location", "topic", "the_topic", "big_topic"])
summaries["retweets_per_tweet"] = summaries["retweet_count"] / summaries["count"]

summaries.to_csv("./tweets_for_analysis.csv", index=False)

# %%
"""
Get counts of tweets by location and big_topic
"""
totals = pd.DataFrame(tweetsDF.groupby(["location", "big_topic"]).count()["id"]).reset_index()
totals.rename(columns = {"id": "count"}, inplace=True)
"""
Get counts of retweets by location and big_topic
"""
retweets = pd.DataFrame(tweetsDF.groupby(["location", "big_topic"]).sum()["retweet_count"]).reset_index()
summaries = totals.merge(retweets, on=["location", "big_topic"])
summaries["retweets_per_tweet"] = summaries["retweet_count"] / summaries["count"]

# %%
import plotly.express as px
for tt in sorted(list(summaries["big_topic"].unique())):
    print(tt)
    
    my_summary = summaries.loc[summaries["big_topic"] == tt].copy()
    fig = px.scatter(my_summary,
                     x="count", 
                     y="retweets_per_tweet", 
                     color="location"
                    )
    
    fig.update_traces(marker=dict(size=12),
                      line=dict(width=2,
                                color='DarkSlateGrey'),
                      selector=dict(mode='markers')
                     )
    
    fig.show()
# Out:
# covid
# <div>                            <div id="198767b4-dcd6-48a9-8059-a5be3d969860" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("198767b4-dcd6-48a9-8059-a5be3d969860")) {                    Plotly.newPlot(                        "198767b4-dcd6-48a9-8059-a5be3d969860",                        [{"hovertemplate": "location=Alameda<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Alameda", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#636efa", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Alameda", "orientation": "v", "showlegend": true, "type": "scatter", "x": [417], "xaxis": "x", "y": [97.46282973621103], "yaxis": "y"}, {"hovertemplate": "location=Albany<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Albany", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#EF553B", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Albany", "orientation": "v", "showlegend": true, "type": "scatter", "x": [811], "xaxis": "x", "y": [22.50924784217016], "yaxis": "y"}, {"hovertemplate": "location=Alum Rock<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Alum Rock", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#00cc96", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Alum Rock", "orientation": "v", "showlegend": true, "type": "scatter", "x": [22], "xaxis": "x", "y": [11.590909090909092], "yaxis": "y"}, {"hovertemplate": "location=Ashland<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Ashland", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#ab63fa", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Ashland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [128], "xaxis": "x", "y": [286.4609375], "yaxis": "y"}, {"hovertemplate": "location=Atherton<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Atherton", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#FFA15A", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Atherton", "orientation": "v", "showlegend": true, "type": "scatter", "x": [210], "xaxis": "x", "y": [5006.342857142857], "yaxis": "y"}, {"hovertemplate": "location=Belmont<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Belmont", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#19d3f3", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Belmont", "orientation": "v", "showlegend": true, "type": "scatter", "x": [283], "xaxis": "x", "y": [2258.0565371024736], "yaxis": "y"}, {"hovertemplate": "location=Berkeley<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Berkeley", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#FF6692", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Berkeley", "orientation": "v", "showlegend": true, "type": "scatter", "x": [822], "xaxis": "x", "y": [94.28588807785889], "yaxis": "y"}, {"hovertemplate": "location=Brisbane<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Brisbane", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#B6E880", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Brisbane", "orientation": "v", "showlegend": true, "type": "scatter", "x": [681], "xaxis": "x", "y": [51.801762114537446], "yaxis": "y"}, {"hovertemplate": "location=Broadmoor<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Broadmoor", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#FF97FF", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Broadmoor", "orientation": "v ...
# politics
# <div>                            <div id="ccf1bb27-ff9d-4ad0-92a8-517cb1eab2fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ccf1bb27-ff9d-4ad0-92a8-517cb1eab2fc")) {                    Plotly.newPlot(                        "ccf1bb27-ff9d-4ad0-92a8-517cb1eab2fc",                        [{"hovertemplate": "location=Alameda<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Alameda", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#636efa", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Alameda", "orientation": "v", "showlegend": true, "type": "scatter", "x": [235], "xaxis": "x", "y": [502.4765957446809], "yaxis": "y"}, {"hovertemplate": "location=Albany<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Albany", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#EF553B", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Albany", "orientation": "v", "showlegend": true, "type": "scatter", "x": [573], "xaxis": "x", "y": [355.4554973821989], "yaxis": "y"}, {"hovertemplate": "location=Alum Rock<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Alum Rock", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#00cc96", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Alum Rock", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8], "xaxis": "x", "y": [3.75], "yaxis": "y"}, {"hovertemplate": "location=Ashland<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Ashland", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#ab63fa", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Ashland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [96], "xaxis": "x", "y": [371.1145833333333], "yaxis": "y"}, {"hovertemplate": "location=Atherton<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Atherton", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#FFA15A", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Atherton", "orientation": "v", "showlegend": true, "type": "scatter", "x": [55], "xaxis": "x", "y": [38956.27272727273], "yaxis": "y"}, {"hovertemplate": "location=Belmont<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Belmont", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#19d3f3", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Belmont", "orientation": "v", "showlegend": true, "type": "scatter", "x": [318], "xaxis": "x", "y": [789.1069182389937], "yaxis": "y"}, {"hovertemplate": "location=Berkeley<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Berkeley", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#FF6692", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Berkeley", "orientation": "v", "showlegend": true, "type": "scatter", "x": [438], "xaxis": "x", "y": [559.2716894977169], "yaxis": "y"}, {"hovertemplate": "location=Brisbane<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Brisbane", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#B6E880", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Brisbane", "orientation": "v", "showlegend": true, "type": "scatter", "x": [115], "xaxis": "x", "y": [5824.452173913043], "yaxis": "y"}, {"hovertemplate": "location=Broadmoor<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Broadmoor", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#FF97FF", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Broadmoor", "orientation": "v", "showlegen ...
# race
# <div>                            <div id="9b9cb89e-c3fe-47f7-8ba7-e92f098e7974" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b9cb89e-c3fe-47f7-8ba7-e92f098e7974")) {                    Plotly.newPlot(                        "9b9cb89e-c3fe-47f7-8ba7-e92f098e7974",                        [{"hovertemplate": "location=Alameda<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Alameda", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#636efa", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Alameda", "orientation": "v", "showlegend": true, "type": "scatter", "x": [117], "xaxis": "x", "y": [13.213675213675213], "yaxis": "y"}, {"hovertemplate": "location=Albany<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Albany", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#EF553B", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Albany", "orientation": "v", "showlegend": true, "type": "scatter", "x": [378], "xaxis": "x", "y": [329.92063492063494], "yaxis": "y"}, {"hovertemplate": "location=Alum Rock<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Alum Rock", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#00cc96", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Alum Rock", "orientation": "v", "showlegend": true, "type": "scatter", "x": [4], "xaxis": "x", "y": [0.75], "yaxis": "y"}, {"hovertemplate": "location=Ashland<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Ashland", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#ab63fa", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Ashland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [48], "xaxis": "x", "y": [2.4791666666666665], "yaxis": "y"}, {"hovertemplate": "location=Atherton<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Atherton", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#FFA15A", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Atherton", "orientation": "v", "showlegend": true, "type": "scatter", "x": [41], "xaxis": "x", "y": [19169.463414634145], "yaxis": "y"}, {"hovertemplate": "location=Belmont<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Belmont", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#19d3f3", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Belmont", "orientation": "v", "showlegend": true, "type": "scatter", "x": [84], "xaxis": "x", "y": [1298.3690476190477], "yaxis": "y"}, {"hovertemplate": "location=Berkeley<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Berkeley", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#FF6692", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Berkeley", "orientation": "v", "showlegend": true, "type": "scatter", "x": [604], "xaxis": "x", "y": [10.78476821192053], "yaxis": "y"}, {"hovertemplate": "location=Brisbane<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Brisbane", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#B6E880", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Brisbane", "orientation": "v", "showlegend": true, "type": "scatter", "x": [119], "xaxis": "x", "y": [15.630252100840336], "yaxis": "y"}, {"hovertemplate": "location=Broadmoor<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "Broadmoor", "line": {"color": "DarkSlateGrey", "width": 2}, "marker": {"color": "#FF97FF", "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Broadmoor", "orientation": "v", "show ...

# %%
import plotly.express as px
for tt in sorted(list(summaries["location"].unique())):
    print(tt)
    
    my_summary = summaries.loc[summaries["location"] == tt].copy()
    fig = px.bar(my_summary,
                     x="count", 
                     y="retweets_per_tweet", 
                     color="big_topic",
                     title=tt
                )
    fig.show()
# Out:
# Alameda
# <div>                            <div id="9ea4be37-cc52-46b3-8f68-123ee5987635" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ea4be37-cc52-46b3-8f68-123ee5987635")) {                    Plotly.newPlot(                        "9ea4be37-cc52-46b3-8f68-123ee5987635",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [417], "xaxis": "x", "y": [97.46282973621103], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [235], "xaxis": "x", "y": [502.4765957446809], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [117], "xaxis": "x", "y": [13.213675213675213], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"] ...
# Albany
# <div>                            <div id="5ff6cb5a-a7c6-4299-bab9-83429fee8f93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ff6cb5a-a7c6-4299-bab9-83429fee8f93")) {                    Plotly.newPlot(                        "5ff6cb5a-a7c6-4299-bab9-83429fee8f93",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [811], "xaxis": "x", "y": [22.50924784217016], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [573], "xaxis": "x", "y": [355.4554973821989], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [378], "xaxis": "x", "y": [329.92063492063494], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"] ...
# Alum Rock
# <div>                            <div id="9df104c2-1adb-4291-bb72-ebb5e909ab95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9df104c2-1adb-4291-bb72-ebb5e909ab95")) {                    Plotly.newPlot(                        "9df104c2-1adb-4291-bb72-ebb5e909ab95",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [22], "xaxis": "x", "y": [11.590909090909092], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [8], "xaxis": "x", "y": [3.75], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [4], "xaxis": "x", "y": [0.75], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b ...
# Ashland
# <div>                            <div id="eb69e763-5bb6-45b2-93ed-805728fc9489" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb69e763-5bb6-45b2-93ed-805728fc9489")) {                    Plotly.newPlot(                        "eb69e763-5bb6-45b2-93ed-805728fc9489",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [128], "xaxis": "x", "y": [286.4609375], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [96], "xaxis": "x", "y": [371.1145833333333], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [48], "xaxis": "x", "y": [2.4791666666666665], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.555 ...
# Atherton
# <div>                            <div id="736efaf7-9d0a-40e4-83d6-0b3d7f098698" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("736efaf7-9d0a-40e4-83d6-0b3d7f098698")) {                    Plotly.newPlot(                        "736efaf7-9d0a-40e4-83d6-0b3d7f098698",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [210], "xaxis": "x", "y": [5006.342857142857], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [55], "xaxis": "x", "y": [38956.27272727273], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [41], "xaxis": "x", "y": [19169.463414634145], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"],  ...
# Belmont
# <div>                            <div id="45002386-cdd3-4995-b010-4d3e44710232" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45002386-cdd3-4995-b010-4d3e44710232")) {                    Plotly.newPlot(                        "45002386-cdd3-4995-b010-4d3e44710232",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [283], "xaxis": "x", "y": [2258.0565371024736], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [318], "xaxis": "x", "y": [789.1069182389937], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [84], "xaxis": "x", "y": [1298.3690476190477], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"] ...
# Berkeley
# <div>                            <div id="4c8fa1e4-cf9f-45c0-b088-be34a8e876b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c8fa1e4-cf9f-45c0-b088-be34a8e876b6")) {                    Plotly.newPlot(                        "4c8fa1e4-cf9f-45c0-b088-be34a8e876b6",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [822], "xaxis": "x", "y": [94.28588807785889], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [438], "xaxis": "x", "y": [559.2716894977169], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [604], "xaxis": "x", "y": [10.78476821192053], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], ...
# Brisbane
# <div>                            <div id="69377b06-d6ae-436e-96ee-44eaabe020f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69377b06-d6ae-436e-96ee-44eaabe020f2")) {                    Plotly.newPlot(                        "69377b06-d6ae-436e-96ee-44eaabe020f2",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [681], "xaxis": "x", "y": [51.801762114537446], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [115], "xaxis": "x", "y": [5824.452173913043], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [119], "xaxis": "x", "y": [15.630252100840336], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786" ...
# Broadmoor
# <div>                            <div id="c1745767-00f6-4c1e-a25b-252d16827b0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1745767-00f6-4c1e-a25b-252d16827b0d")) {                    Plotly.newPlot(                        "c1745767-00f6-4c1e-a25b-252d16827b0d",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [191], "xaxis": "x", "y": [103.98952879581152], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [7], "xaxis": "x", "y": [1.4285714285714286], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3], "xaxis": "x", "y": [0.0], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.555555555555 ...
# Burbank
# <div>                            <div id="e2a86c71-f32b-4e78-8983-be06aa4c9d8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2a86c71-f32b-4e78-8983-be06aa4c9d8c")) {                    Plotly.newPlot(                        "e2a86c71-f32b-4e78-8983-be06aa4c9d8c",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [497], "xaxis": "x", "y": [2038.6881287726358], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [606], "xaxis": "x", "y": [6900.808580858085], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [98], "xaxis": "x", "y": [548.234693877551], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"],  ...
# Burlingame
# <div>                            <div id="c6eed0ee-7fe7-4a75-8f78-82ef04a5be56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6eed0ee-7fe7-4a75-8f78-82ef04a5be56")) {                    Plotly.newPlot(                        "c6eed0ee-7fe7-4a75-8f78-82ef04a5be56",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [10], "xaxis": "x", "y": [5725.4], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [96], "xaxis": "x", "y": [12560.677083333334], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [9], "xaxis": "x", "y": [3675.1111111111113], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.555555555 ...
# Campbell
# ...
# Sunol
# <div>                            <div id="46dd8139-bb1e-469a-9b5b-dfda173fa75a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46dd8139-bb1e-469a-9b5b-dfda173fa75a")) {                    Plotly.newPlot(                        "46dd8139-bb1e-469a-9b5b-dfda173fa75a",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2], "xaxis": "x", "y": [15322.5], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [10], "xaxis": "x", "y": [7243.0], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0. ...
# Union City
# <div>                            <div id="f2d77444-4ef9-4c3e-8f8d-42c20de80bd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2d77444-4ef9-4c3e-8f8d-42c20de80bd9")) {                    Plotly.newPlot(                        "f2d77444-4ef9-4c3e-8f8d-42c20de80bd9",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [343], "xaxis": "x", "y": [80.16909620991254], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [315], "xaxis": "x", "y": [181.93015873015872], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [130], "xaxis": "x", "y": [44.723076923076924], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786" ...
# Woodside
# <div>                            <div id="bf5fbcb9-15ea-44b0-a76c-e6c1580498b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf5fbcb9-15ea-44b0-a76c-e6c1580498b1")) {                    Plotly.newPlot(                        "bf5fbcb9-15ea-44b0-a76c-e6c1580498b1",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#636efa"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [63], "xaxis": "x", "y": [21.841269841269842], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#EF553B"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [25], "xaxis": "x", "y": [6722.6], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>count=%{x}<br>retweets_per_tweet=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [8], "xaxis": "x", "y": [6.875], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "big_topic"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8 ...

# %%
summaries.sort_values("count", ascending=False, inplace=True)
fig = px.bar(summaries,
                 x="location", 
                 y="count", 
                 color="big_topic",
                 barmode="group",
                 title="Big Topics by Location"
            )
fig.show()
# Out:
# <div>                            <div id="fcd8e4d5-58fa-48d4-bbb8-c0502bd5647f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcd8e4d5-58fa-48d4-bbb8-c0502bd5647f")) {                    Plotly.newPlot(                        "fcd8e4d5-58fa-48d4-bbb8-c0502bd5647f",                        [{"alignmentgroup": "True", "hovertemplate": "big_topic=politics<br>location=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "politics", "marker": {"color": "#636efa"}, "name": "politics", "offsetgroup": "politics", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Campbell", "Stanford", "Oakland", "Hayward", "Gilroy", "San Francisco", "Burbank", "Dublin", "Albany", "Berkeley", "Hillsborough", "Belmont", "Union City", "Newark", "Alameda", "Piedmont", "Fairview", "Fremont", "San Jose", "Brisbane", "Santa Clara", "Redwood City", "San Carlos", "Loyola", "Ashland", "Burlingame", "Atherton", "San Mateo", "Livermore", "Palo Alto", "Saratoga", "Monte Sereno", "San Martin", "Pacifica", "Morgan Hill", "Woodside", "Mountain View", "Menlo Park", "Pleasanton", "Sunnyvale", "Milpitas", "Cupertino", "San Leandro", "Sunol", "Castro Valley", "South San Francisco", "Alum Rock", "Los Altos", "Daly City", "Broadmoor", "Half Moon Bay", "Montara", "La Honda", "Los Gatos", "San Bruno", "Emeryville", "Foster City", "East Palo Alto", "Ladera", "Los Altos Hills", "Millbrae", "Portola Valley", "Moss Beach"], "xaxis": "x", "y": [1309, 830, 793, 730, 678, 618, 606, 588, 573, 438, 365, 318, 315, 309, 235, 204, 176, 156, 127, 115, 111, 111, 106, 103, 96, 96, 55, 52, 51, 45, 37, 31, 29, 28, 25, 25, 24, 18, 17, 15, 12, 11, 11, 10, 10, 9, 8, 8, 7, 7, 7, 5, 4, 4, 4, 3, 2, 1, 1, 1, 1, 1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=covid<br>location=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "covid", "marker": {"color": "#EF553B"}, "name": "covid", "offsetgroup": "covid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Campbell", "Dublin", "Livermore", "Stanford", "Berkeley", "Albany", "Brisbane", "San Francisco", "Santa Clara", "Hayward", "Burbank", "Oakland", "Alameda", "Loyola", "Newark", "San Jose", "Gilroy", "Union City", "Saratoga", "Belmont", "Mountain View", "Fremont", "Fairview", "Atherton", "Broadmoor", "Menlo Park", "Hillsborough", "Palo Alto", "Piedmont", "Ashland", "Pacifica", "Pleasanton", "Foster City", "San Mateo", "Woodside", "Half Moon Bay", "South San Francisco", "Milpitas", "Emeryville", "Daly City", "East Palo Alto", "Alum Rock", "Moss Beach", "Cupertino", "Los Gatos", "North Fair Oaks", "Redwood City", "San Leandro", "Burlingame", "San Martin", "San Lorenzo", "Morgan Hill", "Sunnyvale", "Cherryland", "San Carlos", "Montara", "Los Altos", "Castro Valley", "San Bruno", "Millbrae", "Portola Valley", "Sunol", "East Foothills", "Colma", "Pescadero", "La Honda", "Monte Sereno", "Lexington Hills"], "xaxis": "x", "y": [1246, 1099, 1004, 989, 822, 811, 681, 587, 526, 506, 497, 497, 417, 415, 404, 389, 371, 343, 315, 283, 252, 225, 210, 210, 191, 167, 159, 145, 142, 128, 115, 81, 76, 66, 63, 48, 42, 41, 28, 26, 22, 22, 21, 20, 20, 18, 14, 11, 10, 10, 10, 9, 7, 7, 7, 5, 5, 4, 4, 3, 2, 2, 1, 1, 1, 1, 1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "big_topic=race<br>location=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "race", "marker": {"color": "#00cc96"}, "name": "race", "offsetgroup": "race", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Campbell", "Stanford", "Berkeley", "Oakland", "Dublin", "San Francisco", "Albany", "Newark", "Fremont", "Loyola", "Gilroy", "San Jose", "Hayward", "Santa Clara", "Union City", "Brisbane", "Alameda", "Fairview", "Burbank ...

# %%
"""
Get counts of tweets by location and the_topic
"""
totals = pd.DataFrame(tweetsDF.groupby(["location", "the_topic"]).count()["id"]).reset_index()
totals.rename(columns = {"id": "count"}, inplace=True)
"""
Get counts of retweets by location and the_topic
"""
retweets = pd.DataFrame(tweetsDF.groupby(["location", "the_topic"]).sum()["retweet_count"]).reset_index()
summaries = totals.merge(retweets, on=["location", "the_topic"])
summaries["retweets_per_tweet"] = summaries["retweet_count"] / summaries["count"]
print(len(summaries))
summaries.head()
# Out:
# 635
#   location the_topic  count  retweet_count  retweets_per_tweet
# 0  Alameda   Alameda    524        90551.0          172.807252
# 1  Alameda     biden     44           25.0            0.568182
# 2  Alameda     black    112         1546.0           13.803571
# 3  Alameda    corona     12           18.0            1.500000
# 4  Alameda     covid    283        40263.0          142.272085

# %%
summaries.sort_values("retweets_per_tweet", ascending=False, inplace=True)
fig = px.bar(summaries,
                 x="the_topic", 
                 y="count", 
                 color="location",
                 barmode="group",
                 title="Topics by Location"
            )
fig.show()
# Out:
# <div>                            <div id="1e7403f3-b0a2-4a0a-aa73-7fe683b1ad80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e7403f3-b0a2-4a0a-aa73-7fe683b1ad80")) {                    Plotly.newPlot(                        "1e7403f3-b0a2-4a0a-aa73-7fe683b1ad80",                        [{"alignmentgroup": "True", "hovertemplate": "location=Montara<br>the_topic=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Montara", "marker": {"color": "#636efa"}, "name": "Montara", "offsetgroup": "Montara", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["trump", "covid", "biden", "Montara", "virus"], "xaxis": "x", "y": [3, 3, 2, 134, 2], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "location=Castro Valley<br>the_topic=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Castro Valley", "marker": {"color": "#EF553B"}, "name": "Castro Valley", "offsetgroup": "Castro Valley", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["biden", "Castro Valley", "black", "elections", "pandemic", "trump", "republican"], "xaxis": "x", "y": [5, 228, 13, 3, 4, 1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "location=Atherton<br>the_topic=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Atherton", "marker": {"color": "#00cc96"}, "name": "Atherton", "offsetgroup": "Atherton", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["trump", "biden", "black", "virus", "pandemic", "covid", "Atherton", "elections", "racial", "vaccine"], "xaxis": "x", "y": [33, 12, 23, 46, 25, 125, 578, 10, 18, 14], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "location=Loyola<br>the_topic=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Loyola", "marker": {"color": "#ab63fa"}, "name": "Loyola", "offsetgroup": "Loyola", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["corona", "trump", "black", "pandemic", "biden", "covid", "Loyola", "racial", "racism", "elections", "democrat", "republican", "virus"], "xaxis": "x", "y": [6, 57, 187, 219, 26, 187, 585, 21, 36, 3, 12, 5, 3], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "location=Piedmont<br>the_topic=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Piedmont", "marker": {"color": "#FFA15A"}, "name": "Piedmont", "offsetgroup": "Piedmont", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["republican", "Piedmont", "racial", "trump", "elections", "virus", "biden", "pandemic", "covid", "black", "vaccine", "democrat", "corona"], "xaxis": "x", "y": [118, 518, 11, 37, 44, 5, 2, 16, 114, 14, 6, 3, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "location=Burlingame<br>the_topic=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Burlingame", "marker": {"color": "#19d3f3"}, "name": "Burlingame", "offsetgroup": "Burlingame", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["democrat", "republican", "trump", "biden", "Burlingame", "covid", "black", "racial", "corona"], "xaxis": "x", "y": [11, 4, 48, 33, 368, 9, 7, 2, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "location=Woodside<br>the_topic=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Woodside", "marker": {"color": "#FF6692"}, "name": "Woodside", "offsetgroup": "Woodside", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["biden", "Woodside", "virus", "corona", "covid", "black", "pandemic", "trump", "elections", "republican", "racism", "democrat"], "xaxis": "x", "y": [6, 465, 1, 32, 24, 7, 6, 9, 6, 3, 1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "location=Hayward<br>the_topic=%{x}<br>c ...
